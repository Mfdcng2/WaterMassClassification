# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import tempfile, os
import gsw
from sklearn.mixture import GaussianMixture
from joblib import Parallel, delayed, cpu_count
import tqdm
from funcs import water_mass_fraction_plot_kate

# %%
df = pd.read_csv('../../../WMA_fractions_v2.csv',skiprows=1)

# %%
water_mass_fraction_plot_kate(df,7,
    -180,
    tol=0.5,
    start_lat=70.0,
    start_lon=-140.0,
    max_depth=850,
    depth_bin_size=10,
    dist_bin_size=2.2,
    browser=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 water_mass_fraction_plot_kate(df,7,
#       2     -180,
#       3     tol=0.5,
#       4     start_lat=70.0,
#
# File ~/PhD/WM_class/WaterMassClassification/Paper1/Cluster_n_sensitivity/funcs.py:1000, in water_mass_fraction_plot_kate(df, n_clusters, lon_value, tol, start_lat, start_lon, max_depth, depth_bin_size, dist_bin_size, browser)
#     998 # Formatting
#     999 ax.set_ylim(max_depth, 0)
# -> 1000 ax.set_title({col}.replace('_', ' ').replace('[fraction]', '').title())
#    1001 ax.set_xlabel(f'Distance (km) from 70°N, 140°W')
#    1002 ax.set_ylabel('Depth (m)')
#
# AttributeError: 'set' object has no attribute 'replace'
