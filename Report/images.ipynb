# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import tempfile, os
import gsw
from sklearn.mixture import GaussianMixture
from joblib import Parallel, delayed, cpu_count
import tqdm
from funcs import cross_sec_lon, cross_sec_lon_prob, cross_sec_lon_prob2, calc_pv, method34, feature_histograms, plot_geo, plot_3d

# %%
# Get data into dataframe
df = pd.read_csv('../Paper1/Cluster_n_sensitivity/WMA_fractions_v2_with_PV_GMM_ensemble.csv')
